# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

import json # library to handle JSON files

from IPython.display import display_html

# !pip install lxml

# !pip install html5lib

import lxml

# !pip install geopy
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

# !pip install bs4
import requests # library to handle requests
from bs4 import BeautifulSoup # library to parse HTML and XML documents

from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

import folium # map rendering library

print("Libraries imported.")
# Out:
# Collecting lxml
#   Downloading https://files.pythonhosted.org/packages/64/28/0b761b64ecbd63d272ed0e7a6ae6e4402fc37886b59181bfdf274424d693/lxml-4.6.1-cp36-cp36m-manylinux1_x86_64.whl (5.5MB)
#      |████████████████████████████████| 5.5MB 3.4MB/s eta 0:00:01
# Installing collected packages: lxml
# Successfully installed lxml-4.6.1
# Requirement already satisfied: html5lib in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (0.9999999)
# Requirement already satisfied: six in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from html5lib) (1.15.0)
# Collecting geopy
#   Downloading https://files.pythonhosted.org/packages/07/e1/9c72de674d5c2b8fcb0738a5ceeb5424941fefa080bfe4e240d0bacb5a38/geopy-2.0.0-py3-none-any.whl (111kB)
#      |████████████████████████████████| 112kB 5.4MB/s eta 0:00:01
# Collecting geographiclib<2,>=1.49 (from geopy)
#   Downloading https://files.pythonhosted.org/packages/8b/62/26ec95a98ba64299163199e95ad1b0e34ad3f4e176e221c40245f211e425/geographiclib-1.50-py3-none-any.whl
# Installing collected packages: geographiclib, geopy
# Successfully installed geographiclib-1.50 geopy-2.0.0
# Collecting bs4
#   Downloading https://files.pythonhosted.org/packages/10/ed/7e8b97591f6f456174139ec089c769f89a94a1a4025fe967691de971f314/bs4-0.0.1.tar.gz
# Collecting beautifulsoup4 (from bs4)
#   Downloading https://files.pythonhosted.org/packages/d1/41/e6495bd7d3781cee623ce23ea6ac73282a373088fcd0ddc809a047b18eae/beautifulsoup4-4.9.3-py3-none-any.whl (115kB)
#      |████████████████████████████████| 122kB 6.6MB/s eta 0:00:01
# Collecting soupsieve>1.2; python_version >= "3.0" (from beautifulsoup4->bs4)
#   Downloading https://files.pythonhosted.org/packages/6f/8f/457f4a5390eeae1cc3aeab89deb7724c965be841ffca6cfca9197482e470/soupsieve-2.0.1-py3-none-any.whl
# Building wheels for collected packages: bs4
#   Building wheel for bs4 (setup.py) ... done
#   Stored in directory: /home/jupyterlab/.cache/pip/wheels/a0/b0/b2/4f80b9456b87abedbc0bf2d52235414c3467d8889be38dd472
# Successfully built bs4
# Installing collected packages: soupsieve, beautifulsoup4, bs4
# Successfully installed beautifulsoup4-4.9.3 bs4-0.0.1 soupsieve-2.0.1
# Libraries imported.

# %% [markdown]
# ## Extracting data from Wikipedia and cleaning it

# %%
Wiki = pd.read_html('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M')[0]

# %%
Wiki.head()
# Out:
#   Postal Code           Borough              Neighbourhood
# 0         M1A      Not assigned               Not assigned
# 1         M2A      Not assigned               Not assigned
# 2         M3A        North York                  Parkwoods
# 3         M4A        North York           Victoria Village
# 4         M5A  Downtown Toronto  Regent Park, Harbourfront

# %%
Wiki=Wiki[Wiki.Borough != 'Not assigned']

# %%
Wiki.loc[Wiki['Neighbourhood'] == ('Not assigned'), 'Neighbourhood'] = Wiki['Borough']

# %% [markdown]
# ## Getting the latitude and longitude coordenates

# %%
location = pd.read_csv('https://cocl.us/Geospatial_data')

# %%
location.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
df = pd.merge(Wiki, location, on='Postal Code', how='left')

# %%
df.head()
# Out:
#   Postal Code           Borough                                Neighbourhood  \
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
#
#     Latitude  Longitude
# 0  43.753259 -79.329656
# 1  43.725882 -79.315572
# 2  43.654260 -79.360636
# 3  43.718518 -79.464763
# 4  43.662301 -79.389494

# %% [markdown]
# ## Exploring and clustering the neighborhoods in Toronto

# %%
address = 'Toronto, ON'
geolocator = Nominatim(user_agent="Toronto_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.6534817, -79.3839347.

# %%
map_Toronto = folium.Map(location=[latitude, longitude], zoom_start=11)

# %%
for Latitude, Longitude, Borough, Neighbourhood in zip(df['Latitude'], df['Longitude'], df['Borough'], df['Neighbourhood']):
    
    label = folium.Popup(parse_html=True)
    folium.CircleMarker(
        [Latitude, Longitude],
        radius=10,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_Toronto)  
    
map_Toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
borough_names = list(df.Borough.unique())

# %%
borough_toronto = []

for x in borough_names:
    if "toronto" in x.lower():
        borough_toronto.append(x)
        
borough_toronto
# Out:
# ['Downtown Toronto', 'East Toronto', 'West Toronto', 'Central Toronto']

# %%
df = df[df['Borough'].isin(borough_toronto)].reset_index(drop=True)
print(df.shape)
df.head()
# Out:
# (39, 5)
#   Postal Code           Borough                                Neighbourhood  \
# 0         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 1         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
# 2         M5B  Downtown Toronto                     Garden District, Ryerson
# 3         M5C  Downtown Toronto                               St. James Town
# 4         M4E      East Toronto                                  The Beaches
#
#     Latitude  Longitude
# 0  43.654260 -79.360636
# 1  43.662301 -79.389494
# 2  43.657162 -79.378937
# 3  43.651494 -79.375418
# 4  43.676357 -79.293031

# %%
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=11)


for Latitude, Longitude, Postal_Code, Borough, Neighbourhood in zip(df['Latitude'], df['Longitude'], df['Postal Code'], df['Borough'], df['Neighbourhood']):
    label = '{}, {}'.format(Borough, Postal_Code, Neighbourhood)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [Latitude, Longitude],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Define 4square Credentials and Version

# %%
CLIENT_ID = 'S55XCC5SAKMVZIRQ1GDA2BB5T0ZYWAI4JJMVIUCYWPGAR13O' # your Foursquare ID
CLIENT_SECRET = 'IUAZQFZWTMRHEUEY0BVFYG3NXALY141MFSUFD5H3ZMJJIDNW' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: S55XCC5SAKMVZIRQ1GDA2BB5T0ZYWAI4JJMVIUCYWPGAR13O
# CLIENT_SECRET:IUAZQFZWTMRHEUEY0BVFYG3NXALY141MFSUFD5H3ZMJJIDNW

# %% [markdown]
# ## Searching for venues

# %%
search_query = 'coffee'
radius = 500
print(search_query + ' .... OK!')
# Out:
# coffee .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=S55XCC5SAKMVZIRQ1GDA2BB5T0ZYWAI4JJMVIUCYWPGAR13O&client_secret=IUAZQFZWTMRHEUEY0BVFYG3NXALY141MFSUFD5H3ZMJJIDNW&ll=43.6534817,-79.3839347&v=20180605&query=coffee&radius=500&limit=100'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5fa3dda5dc3fa014e6b6eead'},
#  'response': {'venues': [{'id': '59f784dd28122f14f9d5d63d',
#     'name': 'HotBlack Coffee',
#     'location': {'address': '245 Queen Street West',
#      'crossStreet': 'at St Patrick St',
#      'lat': 43.65036434800487,
#      'lng': -79.38866907575726,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65036434800487,
#        'lng': -79.38866907575726}],
#      'distance': 515,
#      'postalCode': 'M5V 1Z4',
#      'cc': 'CA',
#      'neighborhood': 'Entertainment District',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['245 Queen Street West (at St Patrick St)',
#       'Toronto ON M5V 1Z4',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '463001529'},
#     'referralId': 'v-1604574629',
#     'hasPerk': False},
#    {'id': '4b0aaa8ef964a520272623e3',
#     'name': "Timothy's World Coffee",
#     'location': {'address': '483 Bay St, Bell Trinity Square',
#      'crossStreet': 'Bell Trinity Square',
#      'lat': 43.653436,
#      'lng': -79.382314,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.653436,
#        'lng': -79.382314}],
#      'distance': 130,
#      'postalCode': 'M5G 2C9',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['483 Bay St, Bell Trinity Square (Bell Trinity Square)',
#       'Toronto ON M5G 2C9',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604574629',
#     'hasPerk': False},
#    {'id': '4b44fc77f964a520cc0026e3',
#     'name': "Timothy's World Coffee",
#     'location': {'address': '427 University Avenue',
#      'lat': 43.65405317976302,
#      'lng': -79.38808999785911,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65405317976302,
#        'lng': -79.38808999785911}],
#      'distance': 340,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['427 University Avenue', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604574629',
#     'hasPerk': False},
#    {'id': '53e8acc4498ee294fb100183',
#     'name': "Timothy's World Coffee",
#     'location': {'address': '425 University Ave',
#      'crossStreet': 'Dundas',
#      'lat': 43.65427,
#      'lng': -79.387448,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65427,
#        'lng': -79.387448}],
#      'distance': 296,
#      'postalCode': 'M5G 1T6',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['425 University Ave (Dundas)',
#       'Toronto ON M5G 1T6',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604574629',
#     'hasPerk': False},
#    {'id': '4baa9f6cf964a520817a3ae3',
#     'name': "Timothy's World Coffee",
#     'location': {'address': '401 Bay St.',
#      'crossStreet': 'at Richmond St. W',
#      'lat': 43.65213455850074,
#      'lng': -79.38117224696582,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65213455850074,
#        'lng': -79.38117224696582}],
#      'distance': 268,
#      'postalCode': 'M5H 2Y4',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['401 Bay St. (at Richmond St. W)',
#       'Toronto ON M5H 2Y4',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604574629',
#     'hasPerk': False},
#    {'id': '4baa31def964a52037523ae3',
#     'name': 'Coffee office',
#     'location': {'address': '350 Bay St - 7th Floor',
#      'lat': 43.649498,
#      'lng': -79.386479,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.649498,
#        'lng': -79.386479}],
#      'distance': 488,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['350 Bay St - 7th Floor', 'Toronto ON', 'Canada']},
#     'categories': [],
#     'referralId': 'v-1604574629',
#     'hasPerk': False},
#    {'id': '4ec514ec9911232436e364af',
#     'name': "Timothy's World Coffee",
#     'location': {'address': 'Yonge',
#      'crossStreet': 'Dundas',
#      'lat': 43.65669995833159,
#      'lng': -79.37994058195848,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65669995833159,
#        'lng': -79.37994058195848}],
#      'distance': 481,
#      'postalCode': 'M5B 2G9',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Yonge (Dundas)', 'Toronto ON M5B 2G9', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604574629',
#     'hasPerk': False},
#    {'id': '57b1d07b498e85a00ac8baa8',
#     'name': 'Coffee Court',
#     'location': {'lat': 43.652355,
#      'lng': -79.38165,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.652355,
#        'lng': -79.38165}],
#      'distance': 222,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604574629',
#     'hasPerk': False},
#    {'id': '509d036ee4b0912bf20c8abc',
#     'name': 'Treats Coffee Emporium',
#     'location': {'address': 'Bell Trinity Square',
#      'lat': 43.65311707897502,
#      'lng': -79.38230994466748,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65311707897502,
#        'lng': -79.38230994466748}],
#      'distance': 137,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Bell Trinity Square', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604574629',
#     'hasPerk': False},
#    {'id': '5cb326201953f3002c80b633',
#     'name': 'Mos Mos Coffee',
#     'location': {'lat': 43.657547,
#      'lng': -79.3843,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.657547,
#        'lng': -79.3843}],
#      'distance': 453,
#      'postalCode': 'M5G 1H3',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON M5G 1H3', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604574629',
#     'hasPerk': False},
#    {'id': '5287b58f11d214168b94638b',
#     'name': "Seattle's Best Coffee",
#     'location': {'address': '108 Chestnut St',
#      'crossStreet': 'Inside Metropolitan Hotel',
#      'lat': 43.654544830322266,
#      'lng': -79.38590240478516,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.654544830322266,
#        'lng': -79.38590240478516}],
#      'distance': 197,
#      'postalCode': 'M5G 1R3',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['108 Chestnut St (Inside Metropolitan Hotel)',
#       'Toronto ON M5G 1R3',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604574629',
#     'hasPerk': False},
#    {'id': '50046391e4b025b2598516f3',
#     'name': 'Coffee Antidote 9th Floor',
#     'location': {'lat': 43.654360144769974,
#      'lng': -79.3886663553874,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.654360144769974,
#        'lng': -79.3886663553874}],
#      'distance': 393,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604574629',
#     'hasPerk': False},
#    {'id': '5da78e6c4e6c340008c76076',
#     'name': 'Fahrenheit Coffee',
#     'location': {'address': '111 Richmond St',
#      'lat': 43.650361,
#      'lng': -79.383767,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.650361,
#        'lng': -79.383767}],
#      'distance': 347,
#      'postalCode': 'M5H 2G4',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['111 Richmond St', 'Toronto ON M5H 2G4', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604574629',
#     'hasPerk': False},
#    {'id': '4b7bedfbf964a5204e742fe3',
#     'name': 'Coffee Exchange',
#     'location': {'address': '109 McCaul St',
#      'crossStreet': 'Dundas St W (The Grange)',
#      'lat': 43.65373019161559,
#      'lng': -79.39098314529086,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65373019161559,
#        'lng': -79.39098314529086}],
#      'distance': 568,
#      'postalCode': 'M5T 3K5',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['109 McCaul St (Dundas St W (The Grange))',
#       'Toronto ON M5T 3K5',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604574629',
#     'hasPerk': False},
#    {'id': '514627d1e4b0dba1b85e9ba8',
#     'name': 'Dineen Coffee',
#     'location': {'address': '140 Yonge St',
#      'crossStreet': 'at Temperance St',
#      'lat': 43.650497,
#      'lng': -79.378765,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.650497,
#        'lng': -79.378765}],
#      'distance': 532,
#      'postalCode': 'M5C 1X6',
#      'cc': 'CA',
#      'neighborhood': 'Financial District',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['140 Yonge St (at Temperance St)',
#       'Toronto ON M5C 1X6',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604574629',
#     'hasPerk': False},
#    {'id': '4d95ce999079b1f73d82e909',
#     'name': "Smokes'N Coffee",
#     'location': {'lat': 43.656117663066716,
#      'lng': -79.38182656233722,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.656117663066716,
#        'lng': -79.38182656233722}],
#      'distance': 339,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604574629',
#     'hasPerk': False},
#    {'id': '5ba405b62db4a9002c798229',
#     'name': 'Fresh Start Coffee Company',
#     'location': {'address': '595 Bay St',
#      'lat': 43.656374,
#      'lng': -79.383439,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.656374,
#        'lng': -79.383439}],
#      'distance': 324,
#      'postalCode': 'M5G 2B4',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['595 Bay St', 'Toronto ON M5G 2B4', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604574629',
#     'hasPerk': False},
#    {'id': '58e2860dd772f9415f435032',
#     'name': 'google coffee bar',
#     'location': {'lat': 43.650452,
#      'lng': -79.383864,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.650452,
#        'lng': -79.383864}],
#      'distance': 337,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '5665c7b9498e7d8a4f2c0f06',
#       'name': 'Corporate Coffee Shop',
#       'pluralName': 'Corporate Coffee Shops',
#       'shortName': 'Corporate Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604574629',
#     'hasPerk': False},
#    {'id': '5a8b8484c0cacb23056b8412',
#     'name': 'Bulldog Coffee',
#     'location': {'address': '111 Richmond St W',
#      'crossStreet': 'York',
#      'lat': 43.650319,
#      'lng': -79.383831,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.650319,
#        'lng': -79.383831}],
#      'distance': 352,
#      'postalCode': 'M5H 2G4',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['111 Richmond St W (York)',
#       'Toronto ON M5H 2G4',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604574629',
#     'hasPerk': False},
#    {'id': '50b77ec7e4b08ecf5a78a68f',
#     'name': 'Urbana Coffee Co.',
#     'location': {'address': 'Toronto',
#      'lat': 43.65322456230742,
#      'lng': -79.38874882569176,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65322456230742,
#        'lng': -79.38874882569176}],
#      'distance': 388,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604574629',
#     'hasPerk': False},
#    {'id': '5c2d70d4bd4009002c4f500a',
#     'name': 'Cozy Coffee',
#     'location': {'address': '200 Queen St W',
#      'crossStreet': 'St Patrick St',
#      'lat': 43.650535,
#      'lng': -79.388953,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.650535,
#        'lng': -79.388953}],
#      'distance': 520,
#      'postalCode': 'M5V 1Z2',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['200 Queen St W (St Patrick St)',
#       'Toronto ON M5V 1Z2',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604574629',
#     'hasPerk': False},
#    {'id': '4afc5b80f964a520e42122e3',
#     'name': 'Fresh Start Coffee Co.',
#     'location': {'address': '655 Bay St',
#      'crossStreet': 'at Elm St',
#      'lat': 43.657377165116216,
#      'lng': -79.38439256972293,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.657377165116216,
#        'lng': -79.38439256972293}],
#      'distance': 435,
#      'postalCode': 'M5G 2K4',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['655 Bay St (at Elm St)',
#       'Toronto ON M5G 2K4',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604574629',
#     'hasPerk': False},
#    {'id': '537d4d6d498ec171ba22e7fe',
#     'name': "Jimmy's Coffee",
#     'location': {'address': '82 Gerrard Street W',
#      'crossStreet': 'Gerrard & LaPlante',
#      'lat': 43.65842123574496,
#      'lng': -79.38561319551111,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65842123574496,
#        'lng': -79.38561319551111}],
#      'distance': 566,
#      'postalCode': 'M5G 1Z4',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['82 Gerrard Street W (Gerrard & LaPlante)',
#       'Toronto ON M5G 1Z4',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604574629',
#     'hasPerk': False},
#    {'id': '54132b3b498ee9ca9332e189',
#     'name': 'M Square Coffee Co',
#     'location': {'address': 'C24 - 123 Queen St W',
#      'lat': 43.65121797253777,
#      'lng': -79.38355459932247,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65121797253777,
#        'lng': -79.38355459932247}],
#      'distance': 253,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['C24 - 123 Queen St W', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604574629',
#     'hasPerk': False},
#    {'id': '5d493dc5735c2d0007bc3966',
#     'name': 'Bluestone Lane Queen Station Coffee Shop',
#     'location': {'address': '2 Queen Street East',
#      'lat': 43.6525684,
#      'lng': -79.3790471,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6525684,
#        'lng': -79.3790471}],
#      'distance': 406,
#      'postalCode': 'M5C 3G5',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['2 Queen Street East',
#       'Toronto ON M5C 3G5',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604574629',
#     'hasPerk': False},
#    {'id': '4bf424fbe5eba593884e1f90',
#     'name': "Timothy's World Coffee",
#     'location': {'address': '150 York Street',
#      'crossStreet': 'Adelaide',
#      'lat': 43.649242646419395,
#      'lng': -79.38418101332182,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.649242646419395,
#        'lng': -79.38418101332182}],
#      'distance': 472,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['150 York Street (Adelaide)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604574629',
#     'hasPerk': False},
#    {'id': '5a6b737b35f98359eed11974',
#     'name': 'The Library Specialty Coffee',
#     'location': {'address': '281 Dundas St West',
#      'crossStreet': 'St Patrick And Dundas St W',
#      'lat': 43.65441282740799,
#      'lng': -79.39090161351724,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65441282740799,
#        'lng': -79.39090161351724}],
#      'distance': 570,
#      'postalCode': 'M5T 2W5',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['281 Dundas St West (St Patrick And Dundas St W)',
#       'Toronto ON M5T 2W5',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604574629',
#     'hasPerk': False},
#    {'id': '58d2dbe292789f7eb2f51863',
#     'name': 'Union Coffee @ OCADU',
#     'location': {'lat': 43.653084,
#      'lng': -79.391137,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.653084,
#        'lng': -79.391137}],
#      'distance': 581,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604574629',
#     'hasPerk': False},
#    {'id': '4c6bd9de69b4ef3b4d51474e',
#     'name': 'GRIP 6th Floor Coffee Shop',
#     'location': {'address': '179 John St.',
#      'crossStreet': 'at Queen St.',
#      'lat': 43.65103493678703,
#      'lng': -79.39125636590938,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65103493678703,
#        'lng': -79.39125636590938}],
#      'distance': 649,
#      'postalCode': 'M5T 1X4',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['179 John St. (at Queen St.)',
#       'Toronto ON M5T 1X4',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604574629',
#     'hasPerk': False},
#    {'id': '4cf4fc06c9af6dcb8b04af7f',
#     'name': 'Starbucks',
#     'location': {'address': '220 Yonge St, Unit YG-18 Toronto Eaton Centre',
#      'crossStreet': 'Level 2, at Yonge St',
#      'lat': 43.654438,
#      'lng': -79.380699,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.654438,
#        'lng': -79.380699}],
#      'distance': 281,
#      'postalCode': 'M5B 2H1',
#      'cc': 'CA',
#      'neighborhood': 'Downtown Yonge',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['220 Yonge St, Unit YG-18 Toronto Eaton Centre (Level 2, at Yonge St)',
#       'Toronto ON M5B 2H1',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604574629',
#     'hasPerk': False},
#    {'id': '4c057c32d3842d7fd03fbe41',
#     'name': 'Starbucks',
#     'location': {'address': '65 Dundas St. W, Unit 303',
#      'crossStreet': 'at Bay St.',
#      'lat': 43.65596912045543,
#      'lng': -79.38268426666406,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65596912045543,
#        'lng': -79.38268426666406}],
#      'distance': 294,
#      'postalCode': 'M5G 2C5',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['65 Dundas St. W, Unit 303 (at Bay St.)',
#       'Toronto ON M5G 2C5',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604574629',
#     'hasPerk': False},
#    {'id': '4c8fe3216fbf224bb0074f8f',
#     'name': 'Starbucks',
#     'location': {'address': '218 Yonge St, 1-158, Toronto Eaton Centre',
#      'crossStreet': 'Level 1, at the Fountain',
#      'lat': 43.655536,
#      'lng': -79.380933,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.655536,
#        'lng': -79.380933}],
#      'distance': 332,
#      'postalCode': 'M5B 2H6',
#      'cc': 'CA',
#      'neighborhood': 'Downtown Yonge',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['218 Yonge St, 1-158, Toronto Eaton Centre (Level 1, at the Fountain)',
#       'Toronto ON M5B 2H6',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604574629',
#     'hasPerk': False},
#    {'id': '4ae60299f964a52003a421e3',
#     'name': 'Starbucks',
#     'location': {'address': '180 Queen St W, Suite 102.3A',
#      'crossStreet': 'at Simcoe St.',
#      'lat': 43.650751,
#      'lng': -79.388047,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.650751,
#        'lng': -79.388047}],
#      'distance': 449,
#      'postalCode': 'M5V 3X3',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['180 Queen St W, Suite 102.3A (at Simcoe St.)',
#       'Toronto ON M5V 3X3',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604574629',
#     'hasPerk': False},
#    {'id': '4adc55c6f964a520bd2b21e3',
#     'name': 'Starbucks',
#     'location': {'address': '4 King St W',
#      'crossStreet': 'at Yonge St',
#      'lat': 43.649328,
#      'lng': -79.378339,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.649328,
#        'lng': -79.378339}],
#      'distance': 645,
#      'postalCode': 'M5H 1B6',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['4 King St W (at Yonge St)',
#       'Toronto ON M5H 1B6',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604574629',
#     'hasPerk': False},
#    {'id': '4ac6117ff964a520bfb220e3',
#     'name': 'Starbucks',
#     'location': {'address': '250 Queen Street West',
#      'crossStreet': 'at John St',
#      'lat': 43.650043,
#      'lng': -79.391011,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.650043,
#        'lng': -79.391011}],
#      'distance': 686,
#      'postalCode': 'M5V 1Z7',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['250 Queen Street West (at John St)',
#       'Toronto ON M5V 1Z7',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604574629',
#     'hasPerk': False},
#    {'id': '4aef506cf964a5207ad721e3',
#     'name': 'Starbucks',
#     'location': {'address': '1 Queen St E, G5',
#      'crossStreet': 'at Victoria St.',
#      'lat': 43.652221,
#      'lng': -79.378704,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.652221,
#        'lng': -79.378704}],
#      'distance': 444,
#      'postalCode': 'M5C 2W5',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['1 Queen St E, G5 (at Victoria St.)',
#       'Toronto ON M5C 2W5',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604574629',
#     'hasPerk': False},
#    {'id': '4dbae18d4df044e524bbb9de',
#     'name': 'Tim Hortons',
#     'location': {'address': '200 Elizabeth St',
#      'crossStreet': 'Toronto General Hospital - Gerrard/1st Floor',
#      'lat': 43.6584756,
#      'lng': -79.3874523,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6584756,
#        'lng': -79.3874523}],
#      'distance': 623,
#      'postalCode': 'M5G 2C4',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['200 Elizabeth St (Toronto General Hospital - Gerrard/1st Floor)',
#       'Toronto ON M5G 2C4',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604574629',
#     'hasPerk': False},
#    {'id': '514bb359e4b0f65077a8b85c',
#     'name': 'Dutton Employment Law',
#     'location': {'address': '100 King St W',
#      'lat': 43.64889421,
#      'lng': -79.38186312,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64889421,
#        'lng': -79.38186312}],
#      'distance': 537,
#      'postalCode': 'M5X 1C7',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['100 King St W', 'Toronto ON M5X 1C7', 'Canada']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b3f',
#       'name': 'Lawyer',
#       'pluralName': 'Lawyers',
#       'shortName': 'Lawyer',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/lawschool_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604574629',
#     'hasPerk': False},
#    {'id': '598afe9e6661164aee789fff',
#     'name': 'Mos Mos',
#     'location': {'address': '130 King St W',
#      'crossStreet': 'York St',
#      'lat': 43.649057,
#      'lng': -79.3835,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.649057,
#        'lng': -79.3835}],
#      'distance': 493,
#      'postalCode': 'M5X 1K6',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['130 King St W (York St)',
#       'Toronto ON M5X 1K6',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604574629',
#     'hasPerk': False},
#    {'id': '59978605419a9e32cd09c2d1',
#     'name': 'PABLO Toronto パブロ',
#     'location': {'address': '114 Dundas St W',
#      'crossStreet': 'at Bay Street',
#      'lat': 43.65566977573697,
#      'lng': -79.38430330887458,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65566977573697,
#        'lng': -79.38430330887458}],
#      'distance': 245,
#      'postalCode': 'M5G 1C3',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['114 Dundas St W (at Bay Street)',
#       'Toronto ON M5G 1C3',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1604574629',
#     'hasPerk': False}]}}

# %% [markdown]
# ## Geting relevant part of JSON and transforming it into a pandas dataframe

# %%
venues = results['response']['venues']
dataframe = json_normalize(venues)
dataframe.head()
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#                          id                    name  \
# 0  59f784dd28122f14f9d5d63d         HotBlack Coffee
# 1  4b0aaa8ef964a520272623e3  Timothy's World Coffee
# 2  4b44fc77f964a520cc0026e3  Timothy's World Coffee
# 3  53e8acc4498ee294fb100183  Timothy's World Coffee
# 4  4baa9f6cf964a520817a3ae3  Timothy's World Coffee
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1604574629    False
# 1  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1604574629    False
# 2  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1604574629    False
# 3  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1604574629    False
# 4  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1604574629    False
#
#                   location.address location.crossStreet  location.lat  \
# 0            245 Queen Street West     at St Patrick St     43.650364
# 1  483 Bay St, Bell Trinity Square  Bell Trinity Square     43.653436
# 2            427 University Avenue                  NaN     43.654053
# 3               425 University Ave               Dundas     43.654270
# 4                      401 Bay St.    at Richmond St. W     43.652135
#
#    location.lng                            location.labeledLatLngs  \
# 0    -79.388669  [{'label': 'display', 'lat': 43.65036434800487...
# 1    -79.382314  [{'label': 'display', 'lat': 43.653436, 'lng':...
# 2    -79.388090  [{'label': 'display', 'lat': 43.65405317976302...
# 3    -79.387448  [{'label': 'display', 'lat': 43.65427, 'lng': ...
# 4    -79.381172  [{'label': 'display', 'lat': 43.65213455850074...
#
#    location.distance location.postalCode location.cc   location.neighborhood  \
# 0                515             M5V 1Z4          CA  Entertainment District
# 1                130             M5G 2C9          CA                     NaN
# 2                340                 NaN          CA                     NaN
# 3                296             M5G 1T6          CA                     NaN
# 4                268             M5H 2Y4          CA                     NaN
#
#   location.city location.state location.country  \
# 0       Toronto             ON           Canada
# 1       Toronto             ON           Canada
# 2       Toronto             ON           Canada
# 3       Toronto             ON           Canada
# 4       Toronto             ON           Canada
#
#                            location.formattedAddress venuePage.id
# 0  [245 Queen Street West (at St Patrick St), Tor...    463001529
# 1  [483 Bay St, Bell Trinity Square (Bell Trinity...          NaN
# 2        [427 University Avenue, Toronto ON, Canada]          NaN
# 3  [425 University Ave (Dundas), Toronto ON M5G 1...          NaN
# 4  [401 Bay St. (at Richmond St. W), Toronto ON M...          NaN

# %%
coffee_lat=[]
coffee_lon=[]
coffee_name=[]

for i in range(len(venues)):
    coffee_lat.append(venues[i]['location']['lat'])
    coffee_lon.append(venues[i]['location']['lng'])
    coffee_name.append(venues[i]['name'])
    
data={'name':coffee_name,'latitude':coffee_lat,'longitude':coffee_lon}
coffee=pd.DataFrame(data)
coffee.head()
# Out:
#                      name   latitude  longitude
# 0         HotBlack Coffee  43.650364 -79.388669
# 1  Timothy's World Coffee  43.653436 -79.382314
# 2  Timothy's World Coffee  43.654053 -79.388090
# 3  Timothy's World Coffee  43.654270 -79.387448
# 4  Timothy's World Coffee  43.652135 -79.381172

# %%
coffee.groupby(['name']).count()
# Out:
#                                           latitude  longitude
# name
# Bluestone Lane Queen Station Coffee Shop         1          1
# Bulldog Coffee                                   1          1
# Coffee Antidote 9th Floor                        1          1
# Coffee Court                                     1          1
# Coffee Exchange                                  1          1
# Coffee office                                    1          1
# Cozy Coffee                                      1          1
# Dineen Coffee                                    1          1
# Dutton Employment Law                            1          1
# Fahrenheit Coffee                                1          1
# Fresh Start Coffee Co.                           1          1
# Fresh Start Coffee Company                       1          1
# GRIP 6th Floor Coffee Shop                       1          1
# HotBlack Coffee                                  1          1
# Jimmy's Coffee                                   1          1
# M Square Coffee Co                               1          1
# Mos Mos                                          1          1
# Mos Mos Coffee                                   1          1
# PABLO Toronto パブロ                                1          1
# Seattle's Best Coffee                            1          1
# Smokes'N Coffee                                  1          1
# Starbucks                                        7          7
# The Library Specialty Coffee                     1          1
# Tim Hortons                                      1          1
# Timothy's World Coffee                           6          6
# Treats Coffee Emporium                           1          1
# Union Coffee @ OCADU                             1          1
# Urbana Coffee Co.                                1          1
# google coffee bar                                1          1

# %% [markdown]
# ## Clustering

# %% [markdown]
# The idea is to see where is the least dense area at the map. It could be a good place to open new coffee shop.

# %%
map_lat=coffee['latitude'][0]
map_lon=coffee['longitude'][0]
toronto_map=folium.Map(location=[map_lat,map_lon],zoom_start=13)
km=KMeans(n_clusters=6, random_state=0).fit(coffee[['latitude','longitude']])
x=np.arange(6)
ys = [i + x + (i*x)**2 for i in range(6)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]
coffee.insert(0,"cluster",km.labels_)

for lat,long,name,cluster in zip(coffee['latitude'],coffee['longitude'],coffee['name'],coffee['cluster']):
    label='{}'.format(name)
    label=folium.Popup(label,parse_html=True)
    folium.CircleMarker(
        [lat,long],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7,
        parse_html=False).add_to(toronto_map)        
    

toronto_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## In case of a problem with displaying maps the outcome is available here:
# <a href="https://dataplatform.cloud.ibm.com/analytics/notebooks/v2/6d325ba2-2b4a-4e74-94d7-3aa113fbe007/view?access_token=cc3f325b2bb6e3e14c081f45782bb1a77aa31b76e9c0b2dea483ec6ced7c5752"> MAPS </a>
